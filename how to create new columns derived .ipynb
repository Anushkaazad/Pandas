# %%
import pandas as pd

# %%
air_quality = pd.read_csv(r"C:\Users\Anushka\Downloads\air_quality_no2.csv", index_col= 0 ,parse_dates=True)

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
#I want to check the ratio of the values in Paris versus Antwerp and save the result in a new column

air_quality ["ratio_paris_antwerp"] =(
 air_quality ["station_paris"] / air_quality["station_antwerp"]
)

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
#I want to rename the data columns to the corresponding station identifiers used by openAQ
air_quality_renamed = air_quality.rename(
     
    columns= {
        "station_antwerp": "abe234",
        "station_paris": "bqwe13",
        "station_london":"London"
    }
)

# %%
air_quality_renamed .head()
# Out:
#                      abe234  bqwe13  London  london_mg_per_cubic  \
# datetime
# 2019-05-07 02:00:00     NaN     NaN    23.0               43.286
# 2019-05-07 03:00:00    50.5    25.0    19.0               35.758
# 2019-05-07 04:00:00    45.0    27.7    19.0               35.758
# 2019-05-07 05:00:00     NaN    50.4    16.0               30.112
# 2019-05-07 06:00:00     NaN    61.9     NaN                  NaN
#
#                      ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                  NaN
# 2019-05-07 03:00:00             0.495050
# 2019-05-07 04:00:00             0.615556
# 2019-05-07 05:00:00                  NaN
# 2019-05-07 06:00:00                  NaN

# %%
air_quality_renamed =air_quality_renamed.rename(columns = str.lower)

# %%
air_quality_renamed.head()
# Out:
#                      abe234  bqwe13  london  london_mg_per_cubic  \
# datetime
# 2019-05-07 02:00:00     NaN     NaN    23.0               43.286
# 2019-05-07 03:00:00    50.5    25.0    19.0               35.758
# 2019-05-07 04:00:00    45.0    27.7    19.0               35.758
# 2019-05-07 05:00:00     NaN    50.4    16.0               30.112
# 2019-05-07 06:00:00     NaN    61.9     NaN                  NaN
#
#                      ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                  NaN
# 2019-05-07 03:00:00             0.495050
# 2019-05-07 04:00:00             0.615556
# 2019-05-07 05:00:00                  NaN
# 2019-05-07 06:00:00                  NaN

# %%
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
     "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),
    }

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
df["one"]
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
 df["three"] = df["one"] * df["two"]

# %%
df["flag"]= df["one"] > 2

# %%
df
# Out:
#    one  two  three   flag
# a  1.0  1.0    1.0  False
# b  2.0  2.0    4.0  False
# c  3.0  3.0    9.0   True
# d  NaN  4.0    NaN  False

# %%
#Columns can be deleted or popped like with a dict:
del df["two"]

# %%
df
# Out:
#    one  three   flag
# a  1.0    1.0  False
# b  2.0    4.0  False
# c  3.0    9.0   True
# d  NaN    NaN  False

# %%
#other way is popped function
three = df. pop("three")

# %%
df
# Out:
#    one   flag
# a  1.0  False
# b  2.0  False
# c  3.0   True
# d  NaN  False

# %%
#When inserting a scalar value, it will naturally be propagated to fill the column:
df ["foo"] ="bar"

# %%
df
# Out:
#    one   flag  foo
# a  1.0  False  bar
# b  2.0  False  bar
# c  3.0   True  bar
# d  NaN  False  bar

# %%
df["one_turnc"] = df["one"][:2]

# %%
df
# Out:
#    one   flag  foo  one_turnc
# a  1.0  False  bar        1.0
# b  2.0  False  bar        2.0
# c  3.0   True  bar        NaN
# d  NaN  False  bar        NaN

# %%
#insert function using
df.insert(1, "bar", df["one"])

# %%
df
# Out:
#    one  bar   flag  foo  one_turnc
# a  1.0  1.0  False  bar        1.0
# b  2.0  2.0  False  bar        2.0
# c  3.0  3.0   True  bar        NaN
# d  NaN  NaN  False  bar        NaN

# %%
df.insert(2,"bae",df["flag"])

# %%
df
# Out:
#    one  bar    bae   flag  foo  one_turnc
# a  1.0  1.0  False  False  bar        1.0
# b  2.0  2.0  False  False  bar        2.0
# c  3.0  3.0   True   True  bar        NaN
# d  NaN  NaN  False  False  bar        NaN
